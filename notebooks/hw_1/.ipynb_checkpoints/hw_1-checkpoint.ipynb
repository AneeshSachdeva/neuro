# %%
import math
import time
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Hodgkin and Huxley

# %% [markdown]
# ## Model

# %%
class HH(object):
    def __init__(self):
        pass
    
    
    def set(self, step_size=0.001):
        # Constants, v=voltage, g=conductance, c=capacitance, r=rest, l=leak, na=sodium, k=potassium
        self.c = 1.0
        self.v_r = -65.0
        self.v_l = -61.0
        self.v_na = 55.0
        self.v_k = -77.0
        self.g_l = 0.3
        self.g_na = 120.0
        self.g_k = 36.0
        
        # Membrane voltage
        self.v = -65.0
        
        # Set alpha beta variables and activation variables n, m and h
        self.update_alpha_beta()
        self.n = self.a_n/(self.a_n+self.b_n)
        self.m = self.a_m/(self.a_m+self.b_m)
        self.h = self.a_h/(self.a_h+self.b_h)
        
        self.step_size = step_size
        self.time_step = 0
        
        self.records = []
        
        
    def update_alpha_beta(self):
        v_m = self.v_r - self.v
        self.a_n = 0.01 * (v_m + 10)/(math.exp((v_m+10)/10) - 1)
        self.a_m = 0.1 * (v_m + 25)/(math.exp((v_m+25)/10) - 1)
        self.a_h = 0.07 * math.exp(v_m/20)
        self.b_n = 0.125 * math.exp(v_m/80)
        self.b_m = 4.0 * math.exp(v_m/18)
        self.b_h = 1.0 / (math.exp((v_m+30)/10) + 1)
        
        
    def step_time(self, stimulus_current):
        self.update_alpha_beta()

        dndt = self.a_n*(1.0-self.n) - self.b_n*self.n
        dmdt = self.a_m*(1.0-self.m) - self.b_m*self.m
        dhdt = self.a_h*(1.0-self.h) - self.b_h*self.h

        # Calculate current from due to ion electrochemical gradients
        i_k = self.g_k*(self.n**4)*(self.v-self.v_k)
        i_na = self.g_na*(self.m**3)*self.h*(self.v-self.v_na)
        i_l = self.g_l*(self.v-self.v_l)

        i_ion = i_k + i_na + i_l
        dvdt = (stimulus_current - i_ion)/self.c
        i_capacitive = self.c * dvdt

        self.v += self.step_size * dvdt
        self.n += self.step_size * dndt
        self.m += self.step_size * dmdt
        self.h += self.step_size * dhdt
        
        self.time_step += 1
        return i_capacitive, i_k, i_na, i_l
    
    
    def run(self, steps=500, stimulus_time=1000, stimulus_current=20):
        self.set()
        for ii in xrange(steps):
            #i_k, i_na, i_l = 0
            if ii < stimulus_time:
                i_c, i_k, i_na, i_l = self.step_time(stimulus_current=stimulus_current)
            else:
                i_c, i_k, i_na, i_l = self.step_time(stimulus_current=0.0)
            record = {
                'V': self.v,
                'm': self.m,
                'n': self.n,
                'h': self.h,
                'a_m': self.a_m,
                'b_m': self.b_m,
                'a_n': self.a_n,
                'b_n': self.b_n,
                'a_h': self.a_h,
                'b_h': self.b_h,
                'I_Cap': i_c,
                'I_K': i_k,
                'I_Na': i_na,
                'I_Leak': i_l,
                'G_K': self.g_k * (self.n**4),
                'G_Na': self.g_na * (self.m**3) * self.h,
                'time_step': self.time_step
            }
            self.records.append(record)
            
            
    def plot_vs_v(self, values):
        df = pd.DataFrame(self.records)
        for value in values:
            plt.plot(df['v'], df[value])
            plt.ylim(df[value].min(), df[value].max())
            plt.xlim(-110, 50)
            plt.ylabel(value)
            plt.xlabel('mV')
        plt.show()
            
            
    def plot_vs_time(self, values, y_title, title=None, save_file=None):
        df = pd.DataFrame(self.records)
        fig, ax = plt.subplots()
        for value in values:
            ax.plot(df['time_step']*self.step_size, df[value], label=value)
        legend = ax.legend() # call this to set legend
        plt.ylabel(y_title)
        plt.xlabel('seconds')
        if title is not None:
            plt.title(title)
        if save_file is not None:
            plt.savefig(save_file)
        plt.show()

# %% [markdown]
# ## Plots

# %%
model = HH()
rebound_tests = [1, 5, 10, 20, 50, -20] # stimulus current to test rebound/threshold behavior of AP
for stimulus in rebound_tests:
    model.run(steps=25000, stimulus_time=750, stimulus_current=stimulus)
    model.plot_vs_time(['V'], y_title='membrane pot., mV',\
                       title='Membrane pot. vs Time, {}nA Stimulus'.format(stimulus),\
                       save_file='figures/p1_membrane_pot_{}nA.png'.format(stimulus))

model.run(steps=10000, stimulus_time=1000, stimulus_current=20)
model.plot_vs_time(['V'], y_title='Membrane pot., mV', save_file='figures/p1_membrane_pot.png')
model.plot_vs_time(['G_K', 'G_Na'], y_title='Conductance, mS/cm^2', save_file='figures/p1_conductance.png')
model.plot_vs_time(['m', 'n', 'h'], y_title='HH Variables', save_file='figures/p1_hh_vars.png')
model.plot_vs_time(['I_Cap', 'I_K', 'I_Na', 'I_Leak'], y_title='Current, mA/cm^2', save_file='figures/p1_current.png')

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### (TODO)

# %% [markdown]
# # Integrate and Fire (IAF)

# %% [markdown]
# ## Model

# %%
class IAF(object):
    def __init__(self):
        pass
    
    
    def set(self):
        # Constants, r=resistance, c=capacitance, v_thr=volage threshold, v_spk=peak of AP
        self.r = 10
        self.c = 1.0
        self.v_thr = 5.0
        self.v_spk = 70.0
    
        self.v = -0.0
        
        self.input_current = 0.0
        self.spike_count = 0
        self.time_step = 0
        
        self.records = []
        
    
    def step_time(self, step_size=1.0, sinusoidal_current=False, hertz=1.0):
        if sinusoidal_current is False:
            if self.time_step >= 10 and self.time_step <= 60:
                self.input_current = 1.0
            else:
                self.input_current = 0.0
        else:
            frequency = 2 * math.pi * hertz
            self.input_current = math.sin(frequency*(self.time_step*1.0/1000))
            
        old_v = self.v
        if self.v < self.v_thr:
            dvdt = (self.input_current - self.v/self.r)/self.c
            self.v += step_size * dvdt
        elif self.v == self.v_spk:
            self.v = 0.0
        elif self.v >= self.v_thr:
            self.v = self.v_spk
            self.spike_count += 1
        
        self.time_step += 1
        return
        
        
    def run(self, steps=100, sinusoidal_current=False, hertz=1.0):
        self.set()
        for ii in xrange(steps):
            self.step_time(sinusoidal_current=sinusoidal_current, hertz=hertz)
            record = {
                'v': self.v,
                't': self.time_step,
                'input_current': self.input_current,
                'spike_count': self.spike_count
            }
            self.records.append(record)
        
        
    def plot_v(self, title, save_file=None):
        df = pd.DataFrame(self.records)
        plt.plot(df['v'])
        plt.ylabel('voltage (mV)')
        plt.xlabel('milliseconds')
        plt.title(title)
        if save_file is not None:
            plt.savefig(save_file)
        plt.show()
        
        
    def plot_hertz(self, hertz_pannel, save_file=None):
        currents = []
        for hertz in hertz_pannel:
            data = []
            for ii in xrange(1000):
                frequency = 2 * math.pi * hertz
                current = math.sin(frequency*(ii*1.0/1000))
                data.append(current)
            currents.append(data)
        #df = pd.DataFrame.from_dict(results)
        alpha = 1.0
        figure, axarr = plt.subplots(len(hertz_pannel), sharex=True, sharey=True)
        for ii in xrange(len(hertz_pannel)):
            axarr[ii].plot(currents[ii], alpha=alpha)
            #alpha -= 0.20
        plt.xlabel('milliseconds')
        axarr[0].set_title('Stimulus Current (nA)')
        plt.setp([a.get_xticklabels() for a in figure.axes[:-1]], visible=False)
        if save_file is not None:
            plt.savefig(save_file)
        plt.show()

# %%
model = IAF()
hertz_pannel = [1.0, 2.0, 5.0, 10.0, 20.0, 50.0, 100.0]
model.plot_hertz(hertz_pannel, save_file='figures/p2_stimulus_currents.png')
spike_counts = []
for hertz in hertz_pannel:
    model.run(steps=1000, sinusoidal_current=True, hertz=hertz)
    spike_counts.append(model.spike_count)
    model.plot_v(title='Response, {}Hz Stimulus'.format(hertz),\
                 save_file='figures/p2_resposne_{}_hz.png'.format(hertz))
plt.plot([math.log10(y) for y in hertz_pannel], spike_counts)
plt.xlabel('log10(hertz)')
plt.ylabel('total spikes')
plt.title('Spike Count vs Stimulus Frequency')
plt.savefig('figures/p2_spike_count_vs_stimulus.png')
plt.show()

# %% [markdown]
# # Linear-Nonlinear Neuron

# %% [markdown]
# ## Model

# %%
class LNNeuron(object):
    def __init__(self):
        pass
    
    
    def load_data(self, spikes_file, stimulus_file, num_trials=5, trial_size=20000):
        self.all_raw_spikes = np.loadtxt(spikes_file, dtype=float) * 1000 # convert from s to ms
        self.raw_stimulus = np.loadtxt(stimulus_file, dtype=float) 
        
        # Split total raw spikes data into their respective trials
        self.raw_spikes = {}
        trial = 1 # tracks the trial we're collecting
        trial_end = trial_size # this will track the absolute end time of whatever trial we're collecting
        trial_spikes = [] # holds the raw spikes of the trial we're collecting
        for ii in xrange(len(self.all_raw_spikes)):
            raw_spike = self.all_raw_spikes[ii]
            
            # Attribute spike to trial
            if raw_spike < trial_end:
                raw_spike -= (trial - 1) * trial_size # set all trials to be from 0ms-trial_size
                trial_spikes.append(raw_spike)
                
            # Iterate trial
            if raw_spike >= trial_end:
                self.raw_spikes['trial_{}'.format(trial)] = np.array(trial_spikes)
                trial_spikes = []
                trial_end += trial_size
                trial += 1
                
            # Termination cases
            if ii == len(self.all_raw_spikes) - 1:
                self.raw_spikes['trial_{}'.format(trial)] = np.array(trial_spikes)
                break
            elif trial > num_trials:
                break
        
    
    def process_data(self, trial_time=20000, bin_size=100):
        self.spikes = {}
        self.stimulus = []
        
        bins = []
        bin_end = 0
        while bin_end <= trial_time:
            bins.append(bin_end)
            bin_end += bin_size
        
        for trial, raw_spikes in self.raw_spikes.iteritems():
            bin_data = self._digitize(raw_spikes, bins)
            
            self.spikes[trial] = bin_data
           
        self.stimulus = self._digitize(self.raw_stimulus, bins)
        
        
    def train(self, spike_trials, stimulus, stimulus_bins=20):
        # Stimulus
        s = np.matrix(self.rolling_window(stimulus, stimulus_bins))
        
        # Response
        r = np.zeros((len(spike_trials), (len(s))))
#         print r.shape
#         print r.shape[0], r.shape[1]
        for ii in xrange(r.shape[0]):
            spikes = spike_trials[ii]
            for jj in xrange(r.shape[1]):
                r[ii][jj] = spikes[jj+stimulus_bins-1]    
        r = np.matrix(r).transpose()
        
        # Linear regression, L2 penalty
        # Find w that minimizes (r - sw)^2 where sw is predicted response at end of stimulus
        # Closed form solution (TODO: use gradient descent for large dataset):
        sT = s.transpose()
        sTs = sT * s
        sTr = sT * r
        w = np.linalg.inv(sTs) * sTr
        
        # For checking dimmensions
#         print 's', s.shape
#         print 'r', r.shape
#         print 'sT', sT.shape
#         print 'sTs', sTs.shape
#         print 'sTr', sTr.shape
#         print '(sTs)^-1', np.linalg.inv(sTs).shape
#         print 'w', w.shape
        
        return s, w
    
    
    def run(self, s, w):
        r = []
        # Take each sequence of stimulus and multiply it by the linear filter to create a continuous response matrix
        for stim in s:
            r.append((stim * w).item(0)) # get scalar value since output is 1x1 matrix
        return r
        
    
    def _digitize(self, data, bins):
        bin_data = np.zeros(len(bins)-1)
        bin_idx = 0
        x_idx = 0
        while bin_idx <= len(bins) + 2:
            x = data[x_idx]
            if bin_idx == len(bins) - 2:
                if x >= bins[bin_idx]:
                    bin_data[bin_idx] = 1
                    x_idx += 1 
            elif x >= bins[bin_idx] and x < bins[bin_idx+1]:
                bin_data[bin_idx] = 1
                x_idx += 1
            elif x >= bins[bin_idx+1]:
                bin_idx += 1

            if x_idx > len(data) - 1:
                break
        
        return bin_data
    
    
    def rolling_window(self, data, window_size):
        """
        From https://stackoverflow.com/questions/6811183/rolling-window-for-1d-arrays-in-numpy
        @param data: data to roll window along.
        @param window_size: the size of the rolling window.
        """
        shape = data.shape[:-1] + (data.shape[-1] - window_size + 1, window_size)
        strides = data.strides + (data.strides[-1],)
        return np.lib.stride_tricks.as_strided(data, shape=shape, strides=strides)

# %% [markdown]
# ## Train
# ### Trials 1-4, average filter

# %%
model = LNNeuron()
model.load_data(spikes_file='spikes.txt', stimulus_file='stimulus.txt')
model.process_data()
train_spikes = [model.spikes['trial_1'], model.spikes['trial_2'], model.spikes['trial_3'], model.spikes['trial_4']]
s, w1 = model.train(spike_trials=train_spikes, stimulus=model.stimulus, stimulus_bins=20)
w_avg = np.mean(w1, axis=1)
r1 = model.run(s, w_avg)

# %%
plt.plot(w1)
plt.ylabel('weight')
plt.xlabel('100ms bins')
plt.title('Predicted Linear Filters, Trials 1-4')
plt.show()

plt.plot(np.mean(w1, axis=1))
plt.ylabel('weight')
plt.xlabel('100ms bins')
plt.title('Predicted Avg Linear Filter, Trials 1-4')
plt.show()

plt.plot(r1)
plt.ylabel('spike intensity')
plt.xlabel('100ms bins')
plt.title('Predicted Response')
plt.show()

# %% [markdown]
# ### Average of trials 1-4

# %%
model = LNNeuron()
model.load_data(spikes_file='spikes.txt', stimulus_file='stimulus.txt')
model.process_data()
train_spikes = [model.spikes['trial_1'], model.spikes['trial_2'], model.spikes['trial_3'], model.spikes['trial_4']]
s, w2 = model.train(spike_trials=[np.mean(train_spikes, axis=0)], stimulus=model.stimulus, stimulus_bins=20)
r2 = model.run(s, w2)

# %%
plt.plot(w2)
plt.ylabel('weight')
plt.xlabel('100ms bins')
plt.title('Predicted Linear Filter')
plt.show()

plt.plot(r2)
plt.ylabel('spike intensity')
plt.xlabel('100ms bins')
plt.title('Predicted Response')
plt.show()

# %% [markdown]
# ## Test
# ### Trial 5

# %%
train_spikes = [model.spikes['trial_5']]
s, w3 = model.train(spike_trials=train_spikes, stimulus=model.stimulus, stimulus_bins=20)
r3_pred = model.run(s, w2) # Use the filter trained from the first 4 trials to 
r3_actual = model.run(s, w3)

# %%
plt.plot(w3)
plt.ylabel('weight')
plt.xlabel('100ms bins')
plt.title('Actual Linear Filter')
plt.show()

plt.plot(r3_pred)
plt.ylabel('spike intensity')
plt.xlabel('100ms bins')
plt.title('Predicted Response')
plt.show()

plt.plot(r3_actual)
plt.ylabel('spike intensity')
plt.xlabel('100ms bins')
plt.title('Actual Response')
plt.show()

# %% [markdown]
# ## Analysis

# %%
r_1_3_diff = np.subtract(r1, r3)
print 'avg predicted error 1', np.mean(r_1_3_diff, axis=0)

r_2_3_diff = np.subtract(r2, r3)
print 'avg predicted error 2', np.mean(r_2_3_diff, axis=0)

w_2_3_diff = np.subtract(w2, w3)
print 'avg weight error', np.mean(w_2_3_diff, axis=0).item(0)
# Out:
# avg predicted error 1 -0.01933352394135388
# avg predicted error 2 -0.0193335239413538
# avg weight error -0.00496709496129

# %%
fig, ax = plt.subplots()
ax.plot(w3, label='actual filter', color='b')
ax.plot(w2, label='predicted filter', color='r')
legend = ax.legend(loc=1) # call this to set legend
plt.ylabel('weight')
plt.xlabel('100ms bins')
plt.title('Predicted Linear Filter vs. Actual Linear Filter')
plt.savefig('figures/p3_predicted_vs_actual_filter.png')
plt.show()

fig, ax = plt.subplots()
ax.plot(r3_actual, label='actual reponse', color='b')
ax.plot(r3_pred, label='predicted response', color='r')
legend = ax.legend(loc=1) # call this to set legend
plt.ylabel('spike intensity')
plt.xlabel('100ms bins')
plt.title('Predicted Response vs. Actual Response')
plt.savefig('figures/p3_predicted_vs_actual_response.png')
plt.show()
