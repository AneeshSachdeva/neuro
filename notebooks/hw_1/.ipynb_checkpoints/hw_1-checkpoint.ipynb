# %%
import math
import time
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Hodgkin and Huxley

# %% [markdown]
# ## Model

# %%
class HH(object):
    def __init__(self):
        pass
    
    
    def set(self):
        # Constants, v=voltage, g=conductance, c=capacitance, r=rest, l=leak, na=sodium, k=potassium
        self.c = 1.0
        self.v_r = -65.0
        self.v_l = -61.0
        self.v_na = 55.0
        self.v_k = -77.0
        self.g_l = -61.0
        self.g_na = 120.0
        self.g_k = 36.0
        
        # Variables
        self.v = -110.0
        self.n = 0
        self.m = 0
        self.h = 0
        self.a_n = 0
        self.a_m = 0
        self.a_h = 0
        self.b_n = 0
        self.b_m = 0
        self.b_h = 0
        
        self.records = []
        
        
    def step_time(self, dvdt, step_size=0.01):
        v_m = self.v
        self.a_n = 0.01 * (v_m + 10)/(math.exp((v_m+10)/10) - 1)
        self.a_m = 0.1 * (v_m + 25)/(math.exp((v_m+25)/10) - 1)
        self.a_h = 0.07 * math.exp(v_m/20)
        self.b_n = 0.125 * math.exp(v_m/80)
        self.b_m = 4.0 * math.exp(v_m/18)
        self.b_h = 1.0 / (math.exp((v_m+30)/10) + 1)

        dndt = self.a_n*(1.0-self.n) - self.b_n*self.n
        dmdt = self.a_m*(1.0-self.m) - self.b_m*self.m
        dhdt = self.a_h*(1.0-self.h) - self.b_h*self.h

        i_k = self.g_k*(self.n**4)*(v_m-self.v_k)
        i_na = self.g_na*(self.m**3)*self.h*(v_m-self.v_na)
        i_l = self.g_l*(v_m-self.v_l)

        i_ion = i_k + i_na + i_l
        i_capacitive = self.c * dvdt

        i_total = i_capacitive + i_ion

        self.v += step_size * dvdt
        self.n += step_size * dndt
        self.m += step_size * dmdt
        self.h += step_size * dhdt

        return i_total, i_ion
    
    
    def run(self, steps=500, input_current=30):
        self.set()
        for ii in xrange(steps):
            i_total, i_ion = self.step_time(dvdt=input_current)
            record = {
                'v': self.v,
                'm': self.m,
                'n': self.h,
                'h': self.h,
                'a_m': self.a_m,
                'b_m': self.b_m
            }
            self.records.append(record)
            
            
    def plot(self, values):
        df = pd.DataFrame(self.records)
        for value in values:
            plt.plot(df['v'], df[value])
            plt.ylim(df[value].min(), df[value].max())
            plt.xlim(-110, 30)
            plt.ylabel(value)
            plt.xlabel('mV')
            plt.show()

# %% [markdown]
# ## Plots

# %%
model = HH()
model.run()
model.plot(['m', 'n', 'h', 'a_m', 'b_m'])

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### (TODO)

# %% [markdown]
# # Integrate and Fire (IAF)

# %% [markdown]
# ## Model

# %%
class IAF(object):
    def __init__(self):
        pass
    
    
    def set(self):
        # Constants, r=resistance, c=capacitance, v_thr=volage threshold, v_spk=peak of AP
        self.r = 10
        self.c = 1.0
        self.v_thr = 5.0
        self.v_spk = 70.0
    
        self.v = -0.0
        
        self.input_current = 0.0
        self.time_step = 0
        
        self.records = []
        
    
    def step_time(self, step_size=1.0):
        if self.time_step >= 10 and self.time_step <= 60:
            self.input_current = 1.0
        else:
            self.input_current = 0.0
            
        old_v = self.v
        if self.v < self.v_thr:
            dvdt = self.input_current
            self.v += self.c * dvdt * step_size
        elif self.v == self.v_spk:
            self.v = 0.0
        elif self.v >= self.v_thr:
            self.v = self.v_spk
            
        output_current = self.v/self.r + self.c*(self.v - old_v)
        
        self.time_step += 1
        return output_current
        
        
    def run(self, steps=100):
        self.set()
        for ii in xrange(steps):
            output_current = self.step_time()
            record = {
                'v': self.v,
                't': self.time_step,
                'input_current': self.input_current,
                'output_current': output_current
            }
            self.records.append(record)
        
        
    def plot_v(self):
        df = pd.DataFrame(self.records)
        plt.plot(df['v'])
        plt.ylabel('mV')
        plt.xlabel('t')
        plt.show()

# %%
model = IAF()
model.run()
model.plot_v()
